# %%
from roboflow import Roboflow
from ultralytics import YOLO

import config.config as cfg

rf = Roboflow(api_key=cfg.ROBOFLOW_API_KEY)
project = rf.workspace("datalab-xz0n5").project("body-segmentation-38twn")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
model = YOLO("yolov8m-seg.pt")  # load a pretrained model (recommended for training)

results = model.train(
    data="body-segmentation-2/data.yaml",
    batch=-1,
    epochs=200,
    imgsz=640,
)
# Out:
# ...
# 100%|██████████| 52.4M/52.4M [00:01<00:00, 46.1MB/s]
# New https://pypi.org/project/ultralytics/8.2.57 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.12.4 torch-2.3.1 CUDA:0 (NVIDIA GeForce RTX 3080 Ti, 11946MiB)
# ...
